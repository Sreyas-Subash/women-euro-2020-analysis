# %%
# !pip install mplsoccer
# Out:
# ...
#   Obtaining dependency information for mplsoccer from https://files.pythonhosted.org/packages/b3/01/207ecc52db11a4e9706e836709bfb8e4583ec514452215b76e8f9b2a9338/mplsoccer-1.2.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for matplotlib>=3.6 from https://files.pythonhosted.org/packages/4d/9c/65830d4a56c47f5283eaa244dc1228c5da9c844a9f999ebcc2e69bf6cc65/matplotlib-3.7.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pillow from https://files.pythonhosted.org/packages/66/d4/054e491f0880bf0119ee79cdc03264e01d5732e06c454da8c69b83a7c8f2/Pillow-10.0.0-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      ---- ----------------------------------- 30.7/293.3 kB ? eta -:--:--
#      ---- ----------------------------------- 30.7/293.3 kB ? eta -:--:--
#      ---- ----------------------------------- 30.7/293.3 kB ? eta -:--:--
# ...

# %% [markdown]
# ## mplsoccer

# %%
from mplsoccer import Pitch, VerticalPitch

# %%
pitch = Pitch()

fig, ax = pitch.draw()

# %%
vpitch = VerticalPitch()

fig, ax = vpitch.draw()

# %%
pitch = Pitch()

fig, axs = pitch.grid(nrows=3, ncols=2)

# %%
pitch = Pitch(half=True)

fig, ax = pitch.draw()

# %%
from mplsoccer.pitch import Pitch
pitch = Pitch(pitch_color='grass', line_color='white', stripe=True)
fig, ax = pitch.draw()

# %%
pitch = Pitch()
# specifying figure size (width, height)
fig, ax = pitch.draw(figsize=(8, 4))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a figure with 2 rows and 2 columns of subplots
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))

# Create some data for plotting
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = x ** 2
y4 = np.exp(x)

# Plotting on the first subplot (top-left)
axs[0, 0].plot(x, y1)
axs[0, 0].set_title('Sine Function')

# Plotting on the second subplot (top-right)
axs[0, 1].plot(x, y2)
axs[0, 1].set_title('Cosine Function')

# Plotting on the third subplot (bottom-left)
axs[1, 0].plot(x, y3)
axs[1, 0].set_title('Squared Function')

# Plotting on the fourth subplot (bottom-right)
axs[1, 1].plot(x, y4)
axs[1, 1].set_title('Exponential Function')

# Adjust spacing between subplots
plt.tight_layout()

# Add a common title for the whole figure
fig.suptitle('Four Subplots')

# Display the figure
plt.show()

# %%
pitch = Pitch(pitch_type='tracab',  # example plotting a tracab pitch
              pitch_length=105, pitch_width=68,
              label=True, axis=True)  # showing axis labels is optional
fig, ax = pitch.draw()

# %%
pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc')
fig, ax = pitch.draw(figsize=(9, 4), constrained_layout=False, tight_layout=True)
fig.set_facecolor('#22312b')

# %% [markdown]
# ## FC Python

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Arc

# %% [markdown]
# ### Outfield

# %%
import matplotlib.pyplot as plt

# Create a figure with a single subplot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# The first argument (1) represents the number of rows in the grid of subplots.
# The second argument (1) represents the number of columns in the grid of subplots.
# The third argument (1) represents the index of the specific subplot you're adding. The indexing starts from 1 and goes row by row, left to right.

plt.plot([0,0],[0,90], color="blue")
plt.plot([0,130],[90,90], color="orange")
plt.plot([130,130],[90,0], color="green")
plt.plot([130,0],[0,0], color="red")
plt.plot([65,65],[0,90], color="pink")

plt.show()

# %% [markdown]
# ### Adding circle and centre

# %%
#Create figure
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Assign circles to variables - do not fill the centre circle!
# (65,45) - centre of the circle
# 9.15 - radius
centreCircle = plt.Circle((65,45),9.15,color="red",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="blue")

#Draw the circles to our plot
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)

plt.show()

# %%
#Create figure
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")

# #Centre Circle/Spot
centreCircle = plt.Circle((65,45),9.15,fill=False)
centreSpot = plt.Circle((65,45),0.8)
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)


# #Create Arc and add it to our plot
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="red")

ax.add_patch(leftArc)

plt.show()

# %%
def createPitch():
    
    #Create figure
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)

    #Pitch Outline & Centre Line
    plt.plot([0,0],[0,90], color="black")
    plt.plot([0,130],[90,90], color="black")
    plt.plot([130,130],[90,0], color="black")
    plt.plot([130,0],[0,0], color="black")
    plt.plot([65,65],[0,90], color="black")
    
    #Left Penalty Area
    plt.plot([16.5,16.5],[65,25],color="black")
    plt.plot([0,16.5],[65,65],color="black")
    plt.plot([16.5,0],[25,25],color="black")
    
    #Right Penalty Area
    plt.plot([130,113.5],[65,65],color="black")
    plt.plot([113.5,113.5],[65,25],color="black")
    plt.plot([113.5,130],[25,25],color="black")
    
    #Left 6-yard Box
    plt.plot([0,5.5],[54,54],color="black")
    plt.plot([5.5,5.5],[54,36],color="black")
    plt.plot([5.5,0.5],[36,36],color="black")
    
    #Right 6-yard Box
    plt.plot([130,124.5],[54,54],color="black")
    plt.plot([124.5,124.5],[54,36],color="black")
    plt.plot([124.5,130],[36,36],color="black")
    
    #Prepare Circles
    centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
    centreSpot = plt.Circle((65,45),0.8,color="black")
    leftPenSpot = plt.Circle((11,45),0.8,color="black")
    rightPenSpot = plt.Circle((119,45),0.8,color="black")
    
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
    rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
    #Tidy Axes
    plt.axis('off')
    
    #Display Pitch
    plt.show()
    
createPitch()

# %% [markdown]
# ## Fifa Field Dimensions

# %% [markdown]
# ![alt text](https://images.ctfassets.net/7q50hkxm6444/45OFmK6lkstAf65HDV7voC/d209a25f96b062b02048bdf10744ec6d/FIFA_FSG_figure_5-3-1_D_M.png "Pitch")

# %%
pitch = Pitch(line_color = "black")
fig, ax = pitch.draw(figsize=(10,7))
x=110
y=45
shotCircle=plt.Circle((x,y),2,color="red", alpha = 0.3)
plt.text(x+1,y-2,'sreyas')
ax.add_patch(shotCircle)
plt.show()
